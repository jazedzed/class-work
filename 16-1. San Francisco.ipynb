# %%
import csv

filename = "san_francisco_weather.csv"
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    print(header_row)
    
    for index, column_header in enumerate(header_row):
        print(index, column_header)
# Out:
# ['\ufeffSTATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'AWND', 'PRCP', 'SNOW', 'SNWD', 'TAVG', 'TMAX', 'TMIN']
# 0 ﻿STATION
# 1 NAME
# 2 LATITUDE
# 3 LONGITUDE
# 4 ELEVATION
# 5 DATE
# 6 AWND
# 7 PRCP
# 8 SNOW
# 9 SNWD
# 10 TAVG
# 11 TMAX
# 12 TMIN

# %%
import csv

# Get high temperatures from file
filename = "san_francisco_weather.csv"
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    highs = []
    for row in reader:
        high = int(row[11])
        highs.append(high)
        
    print(highs)
# Out:
# [56, 62, 64, 66, 66, 60, 61, 59, 60, 60, 58, 60, 67, 72, 73, 73, 67, 67, 67, 66, 68, 65, 69, 64, 65, 66, 59, 65, 63, 58, 60, 59, 58, 56, 55, 55, 52, 56, 59, 59, 57, 56, 56, 67, 66, 62, 63, 61, 62, 62, 67, 69, 66, 63, 71, 62, 60, 65, 61, 63, 60, 60, 62, 68, 63, 64, 67, 71, 66, 69, 72, 76, 69, 76, 68, 66, 71, 73, 69, 65, 65, 64, 71, 62, 62, 65, 71, 60, 61, 57, 59, 61, 64, 60, 63, 74, 82, 78, 64, 72, 64, 67, 71, 68, 65, 73, 64, 63, 63, 79, 69, 63, 66, 67, 60, 62, 64, 69, 86, 90, 86, 73, 67, 68, 66, 67, 64, 65, 66, 67, 75, 84, 92, 91, 84, 72, 67, 68, 68, 71, 71, 70, 69, 67, 72, 72, 68, 72, 78, 65, 68, 72, 67, 67, 68, 71, 71, 70, 87, 77, 73, 73, 67, 73, 84, 70, 65, 75, 86, 72, 75, 66, 68, 71, 69, 69, 73, 75, 73, 80, 82, 76, 76, 73, 68, 71, 69, 72, 76, 75, 74, 72, 69, 68, 76, 81, 78, 74, 74, 74, 78, 76, 77, 76, 83, 90, 77, 77, 74, 73, 72, 72, 72, 69, 70, 75, 74, 77, 70, 74, 70, 77, 79, 77, 77, 74, 74, 73, 72, 70, 75, 73, 74, 77, 75, 75, 74, 74, 74, 74, 71, 80, 75, 83, 74, 76, 76, 75, 72, 7
# ...

# %%
import csv

from matplotlib import pyplot as plt

# Get high temperatures from file
filename = "san_francisco_weather.csv"
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    highs = []
    for row in reader:
        high = int(row[11])
        highs.append(high)
    
# Plot data.
fig = plt.figure(dpi=128, figsize=(8,4))
plt.plot(highs, c='red')

# Format plot.
plt.title("San Francisco daily high temperatures, 2014", fontsize = 24)
plt.xlabel('', fontsize=16)
plt.ylabel("Temperature (F)", fontsize=16)
plt.tick_params(axis="both", which="major", labelsize=16)

plt.show()

# %%
import csv
from datetime import datetime
first_date = datetime.strptime("2014-01-01", "%Y-%m-%d")
print(first_date)
# Out:
# 2014-01-01 00:00:00

# %%
import csv
from datetime import datetime

from matplotlib import pyplot as plt

# Get dates, high temperatures, and low temperatures from file.
filename = "san_francisco_weather.csv"
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    dates, highs, lows = [], [], []
    for row in reader:
        current_date = datetime.strptime(row[5], "%Y-%m-%d")
        dates.append(current_date)
        
        high = int(row[11])
        highs.append(high)
        
        low = int(row[12])
        lows.append(low)
    
# Plot data.
fig = plt.figure(dpi=128, figsize=(8,4))
plt.plot(dates, highs, c="red")
plt.plot(dates, lows, c="blue")

# Format plot.
plt.title("San Francisco daily high and low temperatures, 2014", fontsize = 24)
plt.xlabel('', fontsize=16)
plt.ylabel("Temperature (F)", fontsize=16)
plt.tick_params(axis="both", which="major", labelsize=16)

fig.autofmt_xdate()
plt.ylabel("Temperature (F)", fontsize=16)
plt.tick_params(axis="both", which="major", labelsize=16)

plt.show()

# %%
import csv
from datetime import datetime

from matplotlib import pyplot as plt

# Get dates, high temperatures, and low temperatures from file.
filename = "san_francisco_weather.csv"
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    dates, highs, lows = [], [], []
    for row in reader:
        current_date = datetime.strptime(row[5], "%Y-%m-%d")
        dates.append(current_date)
        
        high = int(row[11])
        highs.append(high)
        
        low = int(row[12])
        lows.append(low)
    
# Plot data.
fig = plt.figure(dpi=128, figsize=(8,4))
plt.plot(dates, highs, c="red", alpha=0.5)
plt.plot(dates, lows, c="blue", alpha=0.5)
plt.fill_between(dates, highs, lows, facecolor="blue", alpha=0.1)

# Format plot.
plt.title("San Francisco daily high and low temperatures, 2014", fontsize = 24)
plt.xlabel('', fontsize=16)
plt.ylabel("Temperature (F)", fontsize=16)
plt.tick_params(axis="both", which="major", labelsize=16)

fig.autofmt_xdate()
plt.ylabel("Temperature (F)", fontsize=16)
plt.tick_params(axis="both", which="major", labelsize=16)

plt.show()

# %% [markdown]
# ### Daily temperatures in San Francisco appear closer to those in Death Valley than those in Sitka.
