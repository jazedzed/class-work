# %%
import csv

filename = "baltimore_weather.csv"
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    print(header_row)
    
    for index, column_header in enumerate(header_row):
        print(index, column_header)
# Out:
# ['\ufeffSTATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'AWND', 'PRCP', 'SNOW', 'SNWD', 'TAVG', 'TMAX', 'TMIN']
# 0 ﻿STATION
# 1 NAME
# 2 LATITUDE
# 3 LONGITUDE
# 4 ELEVATION
# 5 DATE
# 6 AWND
# 7 PRCP
# 8 SNOW
# 9 SNWD
# 10 TAVG
# 11 TMAX
# 12 TMIN

# %%
import csv
from datetime import datetime

from matplotlib import pyplot as plt

# Get precipitation from file.
filename = "baltimore_weather.csv"
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    dates, precipitation = [], []
    for row in reader:
        current_date = datetime.strptime(row[5], "%Y-%m-%d")
        dates.append(current_date)

        precip = float(row[7])
        precipitation.append(precip)
    
# Plot data.
fig = plt.figure(dpi=128, figsize=(8,4))
plt.plot(dates, precipitation, c="blue")

# Format plot.
plt.title("Baltimore daily precipitation, 2014", fontsize = 24)
plt.xlabel('', fontsize=16)
plt.ylabel("Precipitation (inches)", fontsize=16)
plt.tick_params(axis="both", which="major", labelsize=16)

fig.autofmt_xdate()
plt.ylabel("Precipitation (inches)", fontsize=16)
plt.tick_params(axis="both", which="major", labelsize=16)

plt.show()
